# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from PIL import Image
import numpy as np
import shutil
base_folder = r"C:\Users\Sigma\Downloads\ttts\archive\test_data"
cats_folder = os.path.join(base_folder, r"C:\Users\Sigma\Downloads\ttts\archive\test_data\cats")
dogs_folder = os.path.join(base_folder, r"C:\Users\Sigma\Downloads\ttts\archive\test_data\dogs")
output_folder = r"C:\Users\Sigma\Downloads\ttts\after processing"
output_cats_folder = os.path.join(output_folder, r"C:\Users\Sigma\Downloads\ttts\after processing\catsss")
output_dogs_folder = os.path.join(output_folder, r"C:\Users\Sigma\Downloads\ttts\after processing\dogsss")
os.makedirs(output_cats_folder, exist_ok=True)
os.makedirs(output_dogs_folder, exist_ok=True)
target_size = (150, 150)
def process_and_save_images(input_folder, output_folder):
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg','.webp')):
            image_path = os.path.join(input_folder, filename)
            with Image.open(image_path) as img:
                img = img.resize(target_size)
                img_array = np.array(img) / 255.0

                processed_img = Image.fromarray((img_array * 255).astype(np.uint8))
                processed_img.save(os.path.join(output_folder, filename))
process_and_save_images(cats_folder, output_cats_folder)
process_and_save_images(dogs_folder, output_dogs_folder)
print("تمت معالجة الصور وحفظها في المجلدات الجديدة.")
# Out:
# تمت معالجة الصور وحفظها في المجلدات الجديدة.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
from PIL import Image
processed_cats_folder = r"C:\Users\Sigma\Downloads\ttts\after processing\catsss"
processed_dogs_folder = r"C:\Users\Sigma\Downloads\ttts\after processing\dogsss"
augmented_cats_folder = r"C:\Users\Sigma\Downloads\ttts\after processing\catsss"
augmented_dogs_folder = r"C:\Users\Sigma\Downloads\ttts\after processing\dogsss"
os.makedirs(augmented_cats_folder, exist_ok=True)
os.makedirs(augmented_dogs_folder, exist_ok=True)
def augment_images(input_folder, output_folder, num_augmented_images=8):
  datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)


  for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.webp')):
            image_path = os.path.join(input_folder, filename)
            img = Image.open(image_path)
            img = img.resize((150, 150))
            img = img.convert("RGB")
            img_array = np.array(img)

            img_array = np.expand_dims(img_array, axis=0)
            i = 0
            for batch in datagen.flow(img_array, batch_size=1, save_to_dir=output_folder, save_prefix="aug", save_format="jpeg"):
                i += 1
                if i >= num_augmented_images:
                    break
augment_images(processed_cats_folder, augmented_cats_folder)
augment_images(processed_dogs_folder, augmented_dogs_folder)

print("تم إنشاء صور Augmentation جديدة!")
# Out:
# تم إنشاء صور Augmentation جديدة!

# %%
import os
processed_cats_folder = r"C:\Users\Sigma\Downloads\ttts\after processing\catsss"
processed_dogs_folder = r"C:\Users\Sigma\Downloads\ttts\after processing\dogsss"
num_cats = len([f for f in os.listdir(processed_cats_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.webp'))])
num_dogs = len([f for f in os.listdir(processed_dogs_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.webp'))])
print(f"عدد الصور في فئة القطط: {num_cats}")
print(f"عدد الصور في فئة الكلاب: {num_dogs}")
# Out:
# عدد الصور في فئة القطط: 5908
# عدد الصور في فئة الكلاب: 5947

# %%
def analyze_image_dimensions(folder):
    dimensions = []
    for img_name in os.listdir(folder):
        if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.webp')):
            img_path = os.path.join(folder, img_name)
            img = Image.open(img_path)
            dimensions.append(img.size)
    return dimensions
cat_dimensions = analyze_image_dimensions(processed_cats_folder)
dog_dimensions = analyze_image_dimensions(processed_dogs_folder)
print("أبعاد صور القطط: ", set(cat_dimensions))
print("أبعاد صور الكلاب: ", set(dog_dimensions))
# Out:
# أبعاد صور القطط:  {(150, 150)}
# أبعاد صور الكلاب:  {(150, 150)}

# %%
import matplotlib.pyplot as plt
labels = ['cat', 'dogs']
sizes = [num_cats, num_dogs]
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.axis('equal')  # لضمان أن الدائرة ستكون دائرية
plt.title('distrubuted of cat and dogs ')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_dir = r"C:\Users\Sigma\Downloads\ttts\after processing"
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)  # إعادة قياس الصور وقسم البيانات
train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='training'
)
validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 9484 images belonging to 2 classes.
# Found 2370 images belonging to 2 classes.

# %%
import numpy as np
X_train, y_train = [], []
for i in range(len(train_generator)):
    X_batch, y_batch = train_generator[i]
    X_train.extend(X_batch)
    y_train.extend(y_batch)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_val, y_val = [], []
for i in range(len(validation_generator)):
    X_batch, y_batch = validation_generator[i]
    X_val.extend(X_batch)
    y_val.extend(y_batch)
X_val = np.array(X_val)
y_val = np.array(y_val)

# %%
# !pip install scikeras
from keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
X_train_flattened = X_train.reshape(X_train.shape[0], -1)
X_test_flattened = X_val.reshape(X_val.shape[0], -1)

# %% [markdown]
# ## NN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report
def create_model():
    model = Sequential()
    model.add(Dense(units=128, activation='relu', input_shape=(150 * 150 * 3,)))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(units=32, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

model = create_model()

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("ANN_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train_flattened, y_train,
    batch_size=32,
    epochs=50,
    validation_data=(X_test_flattened, y_val),
    callbacks=[checkpoint, early_stopping, learning_rate_reduction]
)
y_pred = (model.predict(X_test_flattened) > 0.5).astype("int32")
print('Classification Report:\n', classification_report(y_val, y_pred))
# Out:
# Epoch 1/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.5217 - loss: 0.7398
# Epoch 1: val_accuracy improved from -inf to 0.54231, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 70s 223ms/step - accuracy: 0.5218 - loss: 0.7397 - val_accuracy: 0.5423 - val_loss: 0.6819 - learning_rate: 1.0000e-04
# Epoch 2/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.5521 - loss: 0.6864
# Epoch 2: val_accuracy did not improve from 0.54231
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 76s 204ms/step - accuracy: 0.5521 - loss: 0.6864 - val_accuracy: 0.5299 - val_loss: 0.6888 - learning_rate: 1.0000e-04
# Epoch 3/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.5523 - loss: 0.6824
# Epoch 3: val_accuracy improved from 0.54231 to 0.58675, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 198ms/step - accuracy: 0.5524 - loss: 0.6824 - val_accuracy: 0.5868 - val_loss: 0.6661 - learning_rate: 1.0000e-04
# Epoch 4/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5773 - loss: 0.6729
# Epoch 4: val_accuracy did not improve from 0.58675
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 83s 200ms/step - accuracy: 0.5773 - loss: 0.6729 - val_accuracy: 0.5863 - val_loss: 0.6715 - learning_rate: 1.0000e-04
# Epoch 5/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5677 - loss: 0.6737
# Epoch 5: val_accuracy did not improve from 0.58675
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 44s 151ms/step - accuracy: 0.5677 - loss: 0.6737 - val_accuracy: 0.5795 - val_loss: 0.6652 - learning_rate: 1.0000e-04
# Epoch 6/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.5890 - loss: 0.6611
# Epoch 6: val_accuracy improved from 0.58675 to 0.59744, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 89s 176ms/step - accuracy: 0.5890 - loss: 0.6611 - val_accuracy: 0.5974 - val_loss: 0.6574 - learning_rate: 1.0000e-04
# Epoch 7/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5935 - loss: 0.6578
# Epoch 7: val_accuracy improved from 0.59744 to 0.61282, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 78s 165ms/step - accuracy: 0.5935 - loss: 0.6578 - val_accuracy: 0.6128 - val_loss: 0.6501 - learning_rate: 1.0000e-04
# Epoch 8/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6089 - loss: 0.6532
# Epoch 8: val_accuracy did not improve from 0.61282
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 79s 156ms/step - accuracy: 0.6089 - loss: 0.6532 - val_accuracy: 0.5872 - val_loss: 0.6583 - learning_rate: 1.0000e-04
# Epoch 9/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6107 - loss: 0.6467
# Epoch 9: val_accuracy improved from 0.61282 to 0.61538, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 150ms/step - accuracy: 0.6107 - loss: 0.6467 - val_accuracy: 0.6154 - val_loss: 0.6534 - learning_rate: 1.0000e-04
# Epoch 10/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6128 - loss: 0.6411
# Epoch 10: val_accuracy improved from 0.61538 to 0.61752, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 50s 171ms/step - accuracy: 0.6127 - loss: 0.6411 - val_accuracy: 0.6175 - val_loss: 0.6439 - learning_rate: 1.0000e-04
# Epoch 11/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6257 - loss: 0.6413
# Epoch 11: val_accuracy did not improve from 0.61752
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 79s 161ms/step - accuracy: 0.6257 - loss: 0.6413 - val_accuracy: 0.6154 - val_loss: 0.6463 - learning_rate: 1.0000e-04
# Epoch 12/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6237 - loss: 0.6421
# Epoch 12: val_accuracy did not improve from 0.61752
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 43s 148ms/step - accuracy: 0.6237 - loss: 0.6421 - val_accuracy: 0.6154 - val_loss: 0.6485 - learning_rate: 1.0000e-04
# Epoch 13/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6230 - loss: 0.6417
# Epoch 13: val_accuracy did not improve from 0.61752
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 82s 148ms/step - accuracy: 0.6230 - loss: 0.6416 - val_accuracy: 0.6056 - val_loss: 0.6545 - learning_rate: 1.0000e-04
# Epoch 14/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6268 - loss: 0.6278
# Epoch 14: val_accuracy improved from 0.61752 to 0.64060, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 88s 170ms/step - accuracy: 0.6268 - loss: 0.6278 - val_accuracy: 0.6406 - val_loss: 0.6372 - learning_rate: 5.0000e-05
# Epoch 15/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.6341 - loss: 0.6200
# Epoch 15: val_accuracy did not improve from 0.64060
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 79s 158ms/step - accuracy: 0.6342 - loss: 0.6200 - val_accuracy: 0.6248 - val_loss: 0.6362 - learning_rate: 5.0000e-05
# Epoch 16/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6545 - loss: 0.6071
# Epoch 16: val_accuracy did not improve from 0.64060
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 153ms/step - accuracy: 0.6545 - loss: 0.6071 - val_accuracy: 0.6355 - val_loss: 0.6333 - learning_rate: 5.0000e-05
# Epoch 17/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.6531 - loss: 0.6083
# Epoch 17: val_accuracy did not improve from 0.64060
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 84s 159ms/step - accuracy: 0.6531 - loss: 0.6083 - val_accuracy: 0.6244 - val_loss: 0.6421 - learning_rate: 5.0000e-05
# Epoch 18/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6646 - loss: 0.5941
# Epoch 18: val_accuracy did not improve from 0.64060
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 87s 175ms/step - accuracy: 0.6646 - loss: 0.5941 - val_accuracy: 0.6402 - val_loss: 0.6289 - learning_rate: 2.5000e-05
# Epoch 19/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6705 - loss: 0.5953
# Epoch 19: val_accuracy improved from 0.64060 to 0.64274, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 76s 156ms/step - accuracy: 0.6705 - loss: 0.5953 - val_accuracy: 0.6427 - val_loss: 0.6275 - learning_rate: 2.5000e-05
# Epoch 20/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6730 - loss: 0.5831
# Epoch 20: val_accuracy did not improve from 0.64274
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 78s 144ms/step - accuracy: 0.6730 - loss: 0.5831 - val_accuracy: 0.6338 - val_loss: 0.6299 - learning_rate: 2.5000e-05
# Epoch 21/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6732 - loss: 0.5871
# Epoch 21: val_accuracy improved from 0.64274 to 0.64615, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 44s 152ms/step - accuracy: 0.6732 - loss: 0.5871 - val_accuracy: 0.6462 - val_loss: 0.6294 - learning_rate: 2.5000e-05
# Epoch 22/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6780 - loss: 0.5827
# Epoch 22: val_accuracy did not improve from 0.64615
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 163ms/step - accuracy: 0.6780 - loss: 0.5827 - val_accuracy: 0.6389 - val_loss: 0.6299 - learning_rate: 2.5000e-05
# Epoch 23/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6885 - loss: 0.5758
# Epoch 23: val_accuracy did not improve from 0.64615
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.6885 - loss: 0.5758 - val_accuracy: 0.6376 - val_loss: 0.6312 - learning_rate: 2.5000e-05
# Epoch 24/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6766 - loss: 0.5794
# Epoch 24: val_accuracy did not improve from 0.64615
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 46s 156ms/step - accuracy: 0.6766 - loss: 0.5794 - val_accuracy: 0.6432 - val_loss: 0.6267 - learning_rate: 2.5000e-05
# Epoch 25/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6888 - loss: 0.5663
# Epoch 25: val_accuracy did not improve from 0.64615
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 79s 147ms/step - accuracy: 0.6888 - loss: 0.5663 - val_accuracy: 0.6444 - val_loss: 0.6235 - learning_rate: 1.2500e-05
# Epoch 26/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6903 - loss: 0.5703
# Epoch 26: val_accuracy improved from 0.64615 to 0.64701, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 90s 176ms/step - accuracy: 0.6903 - loss: 0.5703 - val_accuracy: 0.6470 - val_loss: 0.6254 - learning_rate: 1.2500e-05
# Epoch 27/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6925 - loss: 0.5652
# Epoch 27: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 78s 161ms/step - accuracy: 0.6925 - loss: 0.5652 - val_accuracy: 0.6440 - val_loss: 0.6253 - learning_rate: 1.2500e-05
# Epoch 28/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7013 - loss: 0.5563
# Epoch 28: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 78s 146ms/step - accuracy: 0.7013 - loss: 0.5564 - val_accuracy: 0.6423 - val_loss: 0.6270 - learning_rate: 1.2500e-05
# Epoch 29/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7011 - loss: 0.5645
# Epoch 29: val_accuracy did not improve from 0.64701
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-05.
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 45s 152ms/step - accuracy: 0.7011 - loss: 0.5645 - val_accuracy: 0.6436 - val_loss: 0.6250 - learning_rate: 1.2500e-05
# Epoch 30/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6959 - loss: 0.5595
# Epoch 30: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 91s 182ms/step - accuracy: 0.6959 - loss: 0.5595 - val_accuracy: 0.6423 - val_loss: 0.6225 - learning_rate: 1.0000e-05
# Epoch 31/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7014 - loss: 0.5545
# Epoch 31: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 72s 149ms/step - accuracy: 0.7014 - loss: 0.5545 - val_accuracy: 0.6380 - val_loss: 0.6257 - learning_rate: 1.0000e-05
# Epoch 32/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7017 - loss: 0.5558
# Epoch 32: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 142ms/step - accuracy: 0.7017 - loss: 0.5558 - val_accuracy: 0.6457 - val_loss: 0.6225 - learning_rate: 1.0000e-05
# Epoch 33/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6972 - loss: 0.5577
# Epoch 33: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 155ms/step - accuracy: 0.6972 - loss: 0.5577 - val_accuracy: 0.6466 - val_loss: 0.6230 - learning_rate: 1.0000e-05
# Epoch 34/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7051 - loss: 0.5475
# Epoch 34: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 91s 186ms/step - accuracy: 0.7051 - loss: 0.5475 - val_accuracy: 0.6466 - val_loss: 0.6228 - learning_rate: 1.0000e-05
# Epoch 35/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7052 - loss: 0.5560
# Epoch 35: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 46s 158ms/step - accuracy: 0.7052 - loss: 0.5559 - val_accuracy: 0.6427 - val_loss: 0.6247 - learning_rate: 1.0000e-05
# Epoch 36/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6937 - loss: 0.5584
# Epoch 36: val_accuracy did not improve from 0.64701
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 83s 160ms/step - accuracy: 0.6937 - loss: 0.5584 - val_accuracy: 0.6436 - val_loss: 0.6222 - learning_rate: 1.0000e-05
# Epoch 37/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7064 - loss: 0.5486
# Epoch 37: val_accuracy improved from 0.64701 to 0.64744, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 81s 157ms/step - accuracy: 0.7064 - loss: 0.5486 - val_accuracy: 0.6474 - val_loss: 0.6224 - learning_rate: 1.0000e-05
# Epoch 38/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7076 - loss: 0.5472
# Epoch 38: val_accuracy improved from 0.64744 to 0.64957, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 166ms/step - accuracy: 0.7076 - loss: 0.5472 - val_accuracy: 0.6496 - val_loss: 0.6229 - learning_rate: 1.0000e-05
# Epoch 39/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7068 - loss: 0.5443
# Epoch 39: val_accuracy did not improve from 0.64957
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 160ms/step - accuracy: 0.7068 - loss: 0.5443 - val_accuracy: 0.6496 - val_loss: 0.6214 - learning_rate: 1.0000e-05
# Epoch 40/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7069 - loss: 0.5451
# Epoch 40: val_accuracy did not improve from 0.64957
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 79s 151ms/step - accuracy: 0.7069 - loss: 0.5451 - val_accuracy: 0.6483 - val_loss: 0.6216 - learning_rate: 1.0000e-05
# Epoch 41/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7088 - loss: 0.5454
# Epoch 41: val_accuracy did not improve from 0.64957
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 146ms/step - accuracy: 0.7088 - loss: 0.5454 - val_accuracy: 0.6444 - val_loss: 0.6249 - learning_rate: 1.0000e-05
# Epoch 42/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7002 - loss: 0.5473
# Epoch 42: val_accuracy did not improve from 0.64957
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 160ms/step - accuracy: 0.7002 - loss: 0.5473 - val_accuracy: 0.6470 - val_loss: 0.6243 - learning_rate: 1.0000e-05
# Epoch 43/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7129 - loss: 0.5417
# Epoch 43: val_accuracy did not improve from 0.64957
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 82s 159ms/step - accuracy: 0.7128 - loss: 0.5417 - val_accuracy: 0.6440 - val_loss: 0.6251 - learning_rate: 1.0000e-05
# Epoch 44/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7131 - loss: 0.5399
# Epoch 44: val_accuracy did not improve from 0.64957
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 78s 146ms/step - accuracy: 0.7131 - loss: 0.5399 - val_accuracy: 0.6449 - val_loss: 0.6229 - learning_rate: 1.0000e-05
# Epoch 45/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7181 - loss: 0.5419
# Epoch 45: val_accuracy did not improve from 0.64957
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 82s 149ms/step - accuracy: 0.7181 - loss: 0.5419 - val_accuracy: 0.6470 - val_loss: 0.6224 - learning_rate: 1.0000e-05
# Epoch 46/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7097 - loss: 0.5431
# Epoch 46: val_accuracy improved from 0.64957 to 0.65214, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 47s 161ms/step - accuracy: 0.7097 - loss: 0.5431 - val_accuracy: 0.6521 - val_loss: 0.6206 - learning_rate: 1.0000e-05
# Epoch 47/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7108 - loss: 0.5420
# Epoch 47: val_accuracy did not improve from 0.65214
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 153ms/step - accuracy: 0.7108 - loss: 0.5420 - val_accuracy: 0.6453 - val_loss: 0.6260 - learning_rate: 1.0000e-05
# Epoch 48/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7137 - loss: 0.5420
# Epoch 48: val_accuracy did not improve from 0.65214
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 83s 157ms/step - accuracy: 0.7137 - loss: 0.5420 - val_accuracy: 0.6496 - val_loss: 0.6242 - learning_rate: 1.0000e-05
# Epoch 49/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7164 - loss: 0.5373
# Epoch 49: val_accuracy did not improve from 0.65214
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 80s 150ms/step - accuracy: 0.7164 - loss: 0.5373 - val_accuracy: 0.6462 - val_loss: 0.6247 - learning_rate: 1.0000e-05
# Epoch 50/50
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7178 - loss: 0.5342
# Epoch 50: val_accuracy improved from 0.65214 to 0.65385, saving model to ANN_model.keras
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 165ms/step - accuracy: 0.7177 - loss: 0.5342 - val_accuracy: 0.6538 - val_loss: 0.6214 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 46.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.65      0.66      0.65      1169
#          1.0       0.65      0.65      0.65      1171
#
#     accuracy                           0.65      2340
#    macro avg       0.65      0.65      0.65      2340
# weighted avg       0.65      0.65      0.65      2340

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss")
ax[0].legend(loc='best', shadow=True)
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
ax[1].legend(loc='best', shadow=True)
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

image_path = "/content/golden-retriever-bokeh-labrador-lawn-dogs.jpg"
model_path = "/content/ANN_model.keras"

img = load_img(image_path, target_size=(150, 150))
img_array = img_to_array(img)
img_array = img_array / 255.0
img_flattened = img_array.flatten()
img_flattened = np.expand_dims(img_flattened, axis=0)

model = load_model(model_path)


prediction = model.predict(img_flattened)


if prediction[0][0] > 0.5:
    print(f"The image is a Dog with probability {prediction[0][0]:.2f}")
else:
    print(f"The image is a Cat with probability {1 - prediction[0][0]:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# The image is a Dog with probability 0.91

# %%
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │       8,640,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,001,029 (99.19 MB)
#  Trainable params: 8,667,009 (33.06 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,334,020 (66.12 MB)
# None

# %% [markdown]
# ## NN2

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report
def create_model():
    model = Sequential()
    model.add(Dense(units=128, activation='relu', input_shape=(150 * 150 * 3,)))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(units=32, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

model = create_model()

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("ANN_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train_flattened, y_train,
    batch_size=16,
    epochs=70,
    validation_data=(X_test_flattened, y_val),
    callbacks=[checkpoint, early_stopping, learning_rate_reduction]
)
y_pred = (model.predict(X_test_flattened) > 0.5).astype("int32")
print('Classification Report:\n', classification_report(y_val, y_pred))
# Out:
# Epoch 1/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5274 - loss: 0.7386
# Epoch 1: val_accuracy improved from -inf to 0.56838, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 80s 132ms/step - accuracy: 0.5274 - loss: 0.7385 - val_accuracy: 0.5684 - val_loss: 0.6823 - learning_rate: 1.0000e-04
# Epoch 2/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5398 - loss: 0.6883
# Epoch 2: val_accuracy did not improve from 0.56838
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 90s 147ms/step - accuracy: 0.5398 - loss: 0.6883 - val_accuracy: 0.5577 - val_loss: 0.6820 - learning_rate: 1.0000e-04
# Epoch 3/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5677 - loss: 0.6807
# Epoch 3: val_accuracy did not improve from 0.56838
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 161s 179ms/step - accuracy: 0.5677 - loss: 0.6807 - val_accuracy: 0.5675 - val_loss: 0.6743 - learning_rate: 1.0000e-04
# Epoch 4/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5541 - loss: 0.6832
# Epoch 4: val_accuracy improved from 0.56838 to 0.58974, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 137s 171ms/step - accuracy: 0.5541 - loss: 0.6832 - val_accuracy: 0.5897 - val_loss: 0.6627 - learning_rate: 1.0000e-04
# Epoch 5/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5825 - loss: 0.6676
# Epoch 5: val_accuracy did not improve from 0.58974
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 140s 168ms/step - accuracy: 0.5825 - loss: 0.6676 - val_accuracy: 0.5786 - val_loss: 0.6707 - learning_rate: 1.0000e-04
# Epoch 6/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5808 - loss: 0.6659
# Epoch 6: val_accuracy did not improve from 0.58974
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 141s 167ms/step - accuracy: 0.5808 - loss: 0.6659 - val_accuracy: 0.5735 - val_loss: 0.6745 - learning_rate: 1.0000e-04
# Epoch 7/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5854 - loss: 0.6675
# Epoch 7: val_accuracy did not improve from 0.58974
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 121s 131ms/step - accuracy: 0.5854 - loss: 0.6675 - val_accuracy: 0.5812 - val_loss: 0.6600 - learning_rate: 1.0000e-04
# Epoch 8/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6004 - loss: 0.6528
# Epoch 8: val_accuracy improved from 0.58974 to 0.60684, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 74s 126ms/step - accuracy: 0.6004 - loss: 0.6528 - val_accuracy: 0.6068 - val_loss: 0.6569 - learning_rate: 5.0000e-05
# Epoch 9/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6036 - loss: 0.6496
# Epoch 9: val_accuracy did not improve from 0.60684
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 86s 133ms/step - accuracy: 0.6036 - loss: 0.6496 - val_accuracy: 0.5906 - val_loss: 0.6594 - learning_rate: 5.0000e-05
# Epoch 10/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6199 - loss: 0.6455
# Epoch 10: val_accuracy improved from 0.60684 to 0.62265, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 82s 133ms/step - accuracy: 0.6199 - loss: 0.6455 - val_accuracy: 0.6226 - val_loss: 0.6461 - learning_rate: 5.0000e-05
# Epoch 11/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.6207 - loss: 0.6444
# Epoch 11: val_accuracy improved from 0.62265 to 0.62991, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 100s 170ms/step - accuracy: 0.6207 - loss: 0.6444 - val_accuracy: 0.6299 - val_loss: 0.6441 - learning_rate: 5.0000e-05
# Epoch 12/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.6219 - loss: 0.6403
# Epoch 12: val_accuracy improved from 0.62991 to 0.63462, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 140s 167ms/step - accuracy: 0.6219 - loss: 0.6403 - val_accuracy: 0.6346 - val_loss: 0.6407 - learning_rate: 5.0000e-05
# Epoch 13/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6270 - loss: 0.6271
# Epoch 13: val_accuracy did not improve from 0.63462
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 122s 133ms/step - accuracy: 0.6270 - loss: 0.6271 - val_accuracy: 0.6154 - val_loss: 0.6407 - learning_rate: 5.0000e-05
# Epoch 14/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6199 - loss: 0.6314
# Epoch 14: val_accuracy did not improve from 0.63462
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 74s 126ms/step - accuracy: 0.6199 - loss: 0.6314 - val_accuracy: 0.6090 - val_loss: 0.6825 - learning_rate: 5.0000e-05
# Epoch 15/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6404 - loss: 0.6217
# Epoch 15: val_accuracy did not improve from 0.63462
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 74s 126ms/step - accuracy: 0.6404 - loss: 0.6217 - val_accuracy: 0.6184 - val_loss: 0.6354 - learning_rate: 5.0000e-05
# Epoch 16/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6571 - loss: 0.6054
# Epoch 16: val_accuracy did not improve from 0.63462
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 83s 129ms/step - accuracy: 0.6570 - loss: 0.6054 - val_accuracy: 0.6325 - val_loss: 0.6451 - learning_rate: 2.5000e-05
# Epoch 17/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6562 - loss: 0.6084
# Epoch 17: val_accuracy did not improve from 0.63462
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 74s 126ms/step - accuracy: 0.6562 - loss: 0.6084 - val_accuracy: 0.6342 - val_loss: 0.6260 - learning_rate: 2.5000e-05
# Epoch 18/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6612 - loss: 0.5984
# Epoch 18: val_accuracy improved from 0.63462 to 0.64274, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 81s 125ms/step - accuracy: 0.6612 - loss: 0.5984 - val_accuracy: 0.6427 - val_loss: 0.6286 - learning_rate: 2.5000e-05
# Epoch 19/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6609 - loss: 0.5949
# Epoch 19: val_accuracy did not improve from 0.64274
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 90s 139ms/step - accuracy: 0.6609 - loss: 0.5949 - val_accuracy: 0.6201 - val_loss: 0.6421 - learning_rate: 2.5000e-05
# Epoch 20/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.6710 - loss: 0.5877
# Epoch 20: val_accuracy improved from 0.64274 to 0.64829, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 94s 160ms/step - accuracy: 0.6710 - loss: 0.5877 - val_accuracy: 0.6483 - val_loss: 0.6256 - learning_rate: 2.5000e-05
# Epoch 21/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.6699 - loss: 0.5882
# Epoch 21: val_accuracy did not improve from 0.64829
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 130s 140ms/step - accuracy: 0.6699 - loss: 0.5882 - val_accuracy: 0.6457 - val_loss: 0.6297 - learning_rate: 2.5000e-05
# Epoch 22/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6797 - loss: 0.5875
# Epoch 22: val_accuracy did not improve from 0.64829
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 134s 127ms/step - accuracy: 0.6797 - loss: 0.5875 - val_accuracy: 0.6312 - val_loss: 0.6388 - learning_rate: 2.5000e-05
# Epoch 23/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6681 - loss: 0.5825
# Epoch 23: val_accuracy improved from 0.64829 to 0.65085, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 75s 129ms/step - accuracy: 0.6681 - loss: 0.5825 - val_accuracy: 0.6509 - val_loss: 0.6255 - learning_rate: 2.5000e-05
# Epoch 24/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6772 - loss: 0.5825
# Epoch 24: val_accuracy did not improve from 0.65085
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 77s 132ms/step - accuracy: 0.6772 - loss: 0.5825 - val_accuracy: 0.6338 - val_loss: 0.6424 - learning_rate: 2.5000e-05
# Epoch 25/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6889 - loss: 0.5699
# Epoch 25: val_accuracy did not improve from 0.65085
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 81s 131ms/step - accuracy: 0.6888 - loss: 0.5699 - val_accuracy: 0.6372 - val_loss: 0.6345 - learning_rate: 2.5000e-05
# Epoch 26/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6833 - loss: 0.5728
# Epoch 26: val_accuracy did not improve from 0.65085
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 74s 127ms/step - accuracy: 0.6834 - loss: 0.5728 - val_accuracy: 0.6432 - val_loss: 0.6310 - learning_rate: 2.5000e-05
# Epoch 27/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6868 - loss: 0.5598
# Epoch 27: val_accuracy improved from 0.65085 to 0.65427, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 85s 131ms/step - accuracy: 0.6868 - loss: 0.5598 - val_accuracy: 0.6543 - val_loss: 0.6332 - learning_rate: 1.2500e-05
# Epoch 28/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6963 - loss: 0.5590
# Epoch 28: val_accuracy did not improve from 0.65427
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 80s 128ms/step - accuracy: 0.6963 - loss: 0.5590 - val_accuracy: 0.6538 - val_loss: 0.6267 - learning_rate: 1.2500e-05
# Epoch 29/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.7122 - loss: 0.5493
# Epoch 29: val_accuracy improved from 0.65427 to 0.65513, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 86s 134ms/step - accuracy: 0.7122 - loss: 0.5493 - val_accuracy: 0.6551 - val_loss: 0.6209 - learning_rate: 1.2500e-05
# Epoch 30/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7116 - loss: 0.5446
# Epoch 30: val_accuracy improved from 0.65513 to 0.65769, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 81s 132ms/step - accuracy: 0.7116 - loss: 0.5446 - val_accuracy: 0.6577 - val_loss: 0.6217 - learning_rate: 1.2500e-05
# Epoch 31/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.7139 - loss: 0.5485
# Epoch 31: val_accuracy did not improve from 0.65769
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 85s 138ms/step - accuracy: 0.7139 - loss: 0.5485 - val_accuracy: 0.6457 - val_loss: 0.6237 - learning_rate: 1.2500e-05
# Epoch 32/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7073 - loss: 0.5473
# Epoch 32: val_accuracy did not improve from 0.65769
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 75s 128ms/step - accuracy: 0.7073 - loss: 0.5473 - val_accuracy: 0.6526 - val_loss: 0.6240 - learning_rate: 1.2500e-05
# Epoch 33/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7110 - loss: 0.5486
# Epoch 33: val_accuracy improved from 0.65769 to 0.66239, saving model to ANN_model.keras
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 76s 130ms/step - accuracy: 0.7110 - loss: 0.5486 - val_accuracy: 0.6624 - val_loss: 0.6242 - learning_rate: 1.2500e-05
# Epoch 34/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7206 - loss: 0.5374
# Epoch 34: val_accuracy did not improve from 0.66239
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 84s 133ms/step - accuracy: 0.7206 - loss: 0.5374 - val_accuracy: 0.6530 - val_loss: 0.6259 - learning_rate: 1.2500e-05
# Epoch 35/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7073 - loss: 0.5451
# Epoch 35: val_accuracy did not improve from 0.66239
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 83s 142ms/step - accuracy: 0.7073 - loss: 0.5451 - val_accuracy: 0.6526 - val_loss: 0.6248 - learning_rate: 1.2500e-05
# Epoch 36/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7147 - loss: 0.5390
# Epoch 36: val_accuracy did not improve from 0.66239
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-05.
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 101s 172ms/step - accuracy: 0.7147 - loss: 0.5390 - val_accuracy: 0.6620 - val_loss: 0.6247 - learning_rate: 1.2500e-05
# Epoch 37/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7298 - loss: 0.5199
# Epoch 37: val_accuracy did not improve from 0.66239
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 144s 175ms/step - accuracy: 0.7297 - loss: 0.5199 - val_accuracy: 0.6556 - val_loss: 0.6244 - learning_rate: 1.0000e-05
# Epoch 38/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7176 - loss: 0.5312
# Epoch 38: val_accuracy did not improve from 0.66239
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 100s 170ms/step - accuracy: 0.7176 - loss: 0.5312 - val_accuracy: 0.6547 - val_loss: 0.6267 - learning_rate: 1.0000e-05
# Epoch 39/70
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7133 - loss: 0.5216
# Epoch 39: val_accuracy did not improve from 0.66239
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 136s 160ms/step - accuracy: 0.7133 - loss: 0.5216 - val_accuracy: 0.6560 - val_loss: 0.6281 - learning_rate: 1.0000e-05
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.67      0.62      0.64      1169
#          1.0       0.65      0.69      0.67      1171
#
#     accuracy                           0.66      2340
#    macro avg       0.66      0.66      0.65      2340
# weighted avg       0.66      0.66      0.65      2340

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                      │ (None, 128)                 │       8,640,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,001,029 (99.19 MB)
#  Trainable params: 8,667,009 (33.06 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,334,020 (66.12 MB)
# None

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss")
ax[0].legend(loc='best', shadow=True)
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
ax[1].legend(loc='best', shadow=True)
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## NN3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report
from tensorflow.keras.regularizers import l2
def create_model():
    model = Sequential()
    model.add(Dense(units=128, activation='relu',kernel_regularizer=l2(0.01), input_shape=(150 * 150 * 3,)))
    model.add(Dense(units=128, activation='relu',kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.3))
    model.add(Dense(units=64, activation='relu',,kernel_regularizer=l2(0.01)))
    model.add(Dense(units=32, activation='relu',kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.4))
    model.add(Dense(units=1, activation='sigmoid'))

    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

model = create_model()

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.000001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("ANN_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(
    X_train_flattened, y_train,
    batch_size=32,
    epochs=50,
    validation_data=(X_test_flattened, y_val),
    callbacks=[checkpoint, early_stopping, learning_rate_reduction]
)
y_pred = (model.predict(X_test_flattened) > 0.5).astype("int32")
print('Classification Report:\n', classification_report(y_val, y_pred))

# %%
print(model.summary())

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss")
ax[0].legend(loc='best', shadow=True)
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
ax[1].legend(loc='best', shadow=True)
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report
def create_model():
    model = Sequential()
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(150, 150, 3)))
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(units=256, activation='relu'))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
model = create_model()
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("best_cats_dogs_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=12,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, early_stopping, learning_rate_reduction]
)
y_pred = (model.predict(X_val) > 0.5).astype("int32")
print('Classification Report:\n', classification_report(y_val, y_pred))
# Out:
# Epoch 1/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5294 - loss: 0.6915
# Epoch 1: val_accuracy improved from -inf to 0.62053, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 74s 194ms/step - accuracy: 0.5295 - loss: 0.6914 - val_accuracy: 0.6205 - val_loss: 0.6590 - learning_rate: 1.0000e-04
# Epoch 2/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6598 - loss: 0.6197
# Epoch 2: val_accuracy improved from 0.62053 to 0.68526, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 49s 130ms/step - accuracy: 0.6599 - loss: 0.6197 - val_accuracy: 0.6853 - val_loss: 0.5933 - learning_rate: 1.0000e-04
# Epoch 3/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7201 - loss: 0.5536
# Epoch 3: val_accuracy improved from 0.68526 to 0.72274, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 52s 168ms/step - accuracy: 0.7201 - loss: 0.5536 - val_accuracy: 0.7227 - val_loss: 0.5479 - learning_rate: 1.0000e-04
# Epoch 4/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7699 - loss: 0.4825
# Epoch 4: val_accuracy improved from 0.72274 to 0.73509, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 83s 171ms/step - accuracy: 0.7699 - loss: 0.4825 - val_accuracy: 0.7351 - val_loss: 0.5437 - learning_rate: 1.0000e-04
# Epoch 5/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8262 - loss: 0.3833
# Epoch 5: val_accuracy improved from 0.73509 to 0.78578, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 76s 149ms/step - accuracy: 0.8262 - loss: 0.3833 - val_accuracy: 0.7858 - val_loss: 0.4663 - learning_rate: 1.0000e-04
# Epoch 6/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8780 - loss: 0.2866
# Epoch 6: val_accuracy improved from 0.78578 to 0.79174, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 90s 176ms/step - accuracy: 0.8780 - loss: 0.2866 - val_accuracy: 0.7917 - val_loss: 0.4829 - learning_rate: 1.0000e-04
# Epoch 7/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9186 - loss: 0.2028
# Epoch 7: val_accuracy did not improve from 0.79174
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 33s 112ms/step - accuracy: 0.9186 - loss: 0.2028 - val_accuracy: 0.7858 - val_loss: 0.5465 - learning_rate: 1.0000e-04
# Epoch 8/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9562 - loss: 0.1235
# Epoch 8: val_accuracy did not improve from 0.79174
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 33s 111ms/step - accuracy: 0.9562 - loss: 0.1235 - val_accuracy: 0.7730 - val_loss: 0.6794 - learning_rate: 1.0000e-04
# Epoch 9/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9763 - loss: 0.0819
# Epoch 9: val_accuracy improved from 0.79174 to 0.80409, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 55s 159ms/step - accuracy: 0.9763 - loss: 0.0819 - val_accuracy: 0.8041 - val_loss: 0.6365 - learning_rate: 1.0000e-04
# Epoch 10/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9863 - loss: 0.0454
# Epoch 10: val_accuracy did not improve from 0.80409
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 68s 112ms/step - accuracy: 0.9863 - loss: 0.0455 - val_accuracy: 0.7934 - val_loss: 0.7633 - learning_rate: 1.0000e-04
# Epoch 11/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9907 - loss: 0.0339
# Epoch 11: val_accuracy did not improve from 0.80409
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 41s 111ms/step - accuracy: 0.9907 - loss: 0.0339 - val_accuracy: 0.8020 - val_loss: 0.7428 - learning_rate: 1.0000e-04
# Epoch 12/12
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9912 - loss: 0.0265
# Epoch 12: val_accuracy did not improve from 0.80409
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 41s 111ms/step - accuracy: 0.9912 - loss: 0.0266 - val_accuracy: 0.8007 - val_loss: 0.8073 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 5.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.77      0.82      0.79      1180
#          1.0       0.80      0.76      0.78      1168
#
#     accuracy                           0.79      2348
#    macro avg       0.79      0.79      0.79      2348
# weighted avg       0.79      0.79      0.79      2348

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 8))  # أضف حجم الشكل لتحسين العرض
# الرسم الأول: الخسارة
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss")
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend(loc='best', shadow=True)

# الرسم الثاني: الدقة
ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
ax[1].legend(loc='best', shadow=True)

# عرض الرسوم
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import load_model

# تحميل النموذج
model_path = r"/content/best_cats_dogs_model.keras"
model = load_model(model_path)

# تحميل الصورة ومعالجتها
image_path = r"/content/OIP (6).jpg"
img = load_img(image_path, target_size=(150, 150))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # إضافة بعد إضافي للمصفوفة
img_array = img_array / 255.0  # تحويل القيم لتكون بين 0 و1

# التنبؤ بالفئة باستخدام النموذج
prediction = model.predict(img_array)  # استبدل history بـ model
if prediction[0][0] > 0.5:
    print(f"The image is a *Dog* with probability {prediction[0][0]:.2f}")
else:
    print(f"The image is a *Cat* with probability {1 - prediction[0][0]:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# The image is a *Cat* with probability 0.98

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import load_model

# تحميل النموذج
model_path = r"/content/best_cats_dogs_model.keras"
model = load_model(model_path)

# تحميل الصورة ومعالجتها
image_path = r"/content/OIP (4).jpg"
img = load_img(image_path, target_size=(150, 150))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # إضافة بعد إضافي للمصفوفة
img_array = img_array / 255.0  # تحويل القيم لتكون بين 0 و1

# التنبؤ بالفئة باستخدام النموذج
prediction = model.predict(img_array)  # استبدل history بـ model
if prediction[0][0] > 0.5:
    print(f"The image is a *Dog* with probability {prediction[0][0]:.2f}")
else:
    print(f"The image is a *Cat* with probability {1 - prediction[0][0]:.2f}")
# Out:
# WARNING:tensorflow:5 out of the last 77 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d0c3c54ecb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# The image is a *Cat* with probability 1.00

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import load_model

# تحميل النموذج
model_path = r"/content/best_cats_dogs_model.keras"
model = load_model(model_path)

# تحميل الصورة ومعالجتها
image_path = r"/content/golden-retriever-bokeh-labrador-lawn-dogs.jpg"
img = load_img(image_path, target_size=(150, 150))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # إضافة بعد إضافي للمصفوفة
img_array = img_array / 255.0  # تحويل القيم لتكون بين 0 و1

# التنبؤ بالفئة باستخدام النموذج
prediction = model.predict(img_array)  # استبدل history بـ model
if prediction[0][0] > 0.5:
    print(f"The image is a *Dog* with probability {prediction[0][0]:.2f}")
else:
    print(f"The image is a *Cat* with probability {1 - prediction[0][0]:.2f}")
# Out:
# WARNING:tensorflow:6 out of the last 78 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d0c3c453130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# The image is a *Dog* with probability 0.57

# %%
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 146, 146, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 71, 71, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 69, 69, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 34, 34, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 34, 34, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 147968)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      37,880,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 114,519,749 (436.86 MB)
#  Trainable params: 38,173,249 (145.62 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 76,346,500 (291.24 MB)
# None

# %% [markdown]
# # CNN 2

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report
def create_model():
    model = Sequential()
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(150, 150, 3)))
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(units=256, activation='relu'))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
model = create_model()
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("best_cats_dogs_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=20,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, early_stopping, learning_rate_reduction]
)
y_pred = (model.predict(X_val) > 0.5).astype("int32")
print('Classification Report:\n', classification_report(y_val, y_pred))
# Out:
# Epoch 1/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5216 - loss: 0.6954
# Epoch 1: val_accuracy improved from -inf to 0.61712, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 75s 236ms/step - accuracy: 0.5217 - loss: 0.6953 - val_accuracy: 0.6171 - val_loss: 0.6648 - learning_rate: 1.0000e-04
# Epoch 2/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6357 - loss: 0.6439
# Epoch 2: val_accuracy improved from 0.61712 to 0.65290, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 68s 200ms/step - accuracy: 0.6357 - loss: 0.6439 - val_accuracy: 0.6529 - val_loss: 0.6190 - learning_rate: 1.0000e-04
# Epoch 3/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7060 - loss: 0.5768
# Epoch 3: val_accuracy improved from 0.65290 to 0.71039, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 79s 188ms/step - accuracy: 0.7061 - loss: 0.5768 - val_accuracy: 0.7104 - val_loss: 0.5613 - learning_rate: 1.0000e-04
# Epoch 4/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7669 - loss: 0.4864
# Epoch 4: val_accuracy improved from 0.71039 to 0.76533, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 90s 215ms/step - accuracy: 0.7669 - loss: 0.4864 - val_accuracy: 0.7653 - val_loss: 0.4981 - learning_rate: 1.0000e-04
# Epoch 5/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8296 - loss: 0.3798
# Epoch 5: val_accuracy improved from 0.76533 to 0.78705, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 67s 230ms/step - accuracy: 0.8296 - loss: 0.3798 - val_accuracy: 0.7871 - val_loss: 0.4704 - learning_rate: 1.0000e-04
# Epoch 6/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8838 - loss: 0.2813
# Epoch 6: val_accuracy improved from 0.78705 to 0.79898, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 64s 219ms/step - accuracy: 0.8838 - loss: 0.2813 - val_accuracy: 0.7990 - val_loss: 0.4464 - learning_rate: 1.0000e-04
# Epoch 7/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9246 - loss: 0.1874
# Epoch 7: val_accuracy improved from 0.79898 to 0.80494, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 73s 188ms/step - accuracy: 0.9246 - loss: 0.1874 - val_accuracy: 0.8049 - val_loss: 0.4927 - learning_rate: 1.0000e-04
# Epoch 8/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9580 - loss: 0.1113
# Epoch 8: val_accuracy improved from 0.80494 to 0.80920, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 82s 188ms/step - accuracy: 0.9580 - loss: 0.1113 - val_accuracy: 0.8092 - val_loss: 0.5964 - learning_rate: 1.0000e-04
# Epoch 9/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9811 - loss: 0.0644
# Epoch 9: val_accuracy improved from 0.80920 to 0.81346, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 98s 241ms/step - accuracy: 0.9811 - loss: 0.0644 - val_accuracy: 0.8135 - val_loss: 0.5970 - learning_rate: 1.0000e-04
# Epoch 10/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9876 - loss: 0.0394
# Epoch 10: val_accuracy improved from 0.81346 to 0.81772, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 79s 231ms/step - accuracy: 0.9876 - loss: 0.0394 - val_accuracy: 0.8177 - val_loss: 0.6517 - learning_rate: 1.0000e-04
# Epoch 11/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9918 - loss: 0.0303
# Epoch 11: val_accuracy did not improve from 0.81772
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 46s 110ms/step - accuracy: 0.9918 - loss: 0.0303 - val_accuracy: 0.8032 - val_loss: 0.6939 - learning_rate: 1.0000e-04
# Epoch 12/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9935 - loss: 0.0218
# Epoch 12: val_accuracy did not improve from 0.81772
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 41s 111ms/step - accuracy: 0.9935 - loss: 0.0218 - val_accuracy: 0.8101 - val_loss: 0.6750 - learning_rate: 1.0000e-04
# Epoch 13/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9964 - loss: 0.0144
# Epoch 13: val_accuracy did not improve from 0.81772
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 41s 111ms/step - accuracy: 0.9964 - loss: 0.0144 - val_accuracy: 0.8173 - val_loss: 0.8378 - learning_rate: 1.0000e-04
# Epoch 14/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9980 - loss: 0.0102
# Epoch 14: val_accuracy improved from 0.81772 to 0.81857, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 72s 217ms/step - accuracy: 0.9980 - loss: 0.0102 - val_accuracy: 0.8186 - val_loss: 0.9033 - learning_rate: 5.0000e-05
# Epoch 15/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9993 - loss: 0.0034
# Epoch 15: val_accuracy improved from 0.81857 to 0.82112, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 78s 204ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.8211 - val_loss: 0.9404 - learning_rate: 5.0000e-05
# Epoch 16/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9997 - loss: 0.0026
# Epoch 16: val_accuracy improved from 0.82112 to 0.82624, saving model to best_cats_dogs_model.keras
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 90s 232ms/step - accuracy: 0.9997 - loss: 0.0026 - val_accuracy: 0.8262 - val_loss: 0.9613 - learning_rate: 5.0000e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80      1180
#          1.0       0.80      0.80      0.80      1168
#
#     accuracy                           0.80      2348
#    macro avg       0.80      0.80      0.80      2348
# weighted avg       0.80      0.80      0.80      2348

# %% [markdown]
# # CNN3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report
def create_model():
    model = Sequential()
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(150, 150, 3)))
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(units=256, activation='relu'))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
model = create_model()
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("best_cats_dogs_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    batch_size=16,
    epochs=30,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, early_stopping, learning_rate_reduction]
)
y_pred = (model.predict(X_val) > 0.5).astype("int32")
print('Classification Report:\n', classification_report(y_val, y_pred))
# Out:
# Epoch 1/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5420 - loss: 0.6918
# Epoch 1: val_accuracy improved from -inf to 0.66301, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 76s 101ms/step - accuracy: 0.5420 - loss: 0.6918 - val_accuracy: 0.6630 - val_loss: 0.6447 - learning_rate: 1.0000e-04
# Epoch 2/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6512 - loss: 0.6290
# Epoch 2: val_accuracy improved from 0.66301 to 0.69675, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6512 - loss: 0.6289 - val_accuracy: 0.6968 - val_loss: 0.5794 - learning_rate: 1.0000e-04
# Epoch 3/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7163 - loss: 0.5484
# Epoch 3: val_accuracy improved from 0.69675 to 0.70181, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 52s 87ms/step - accuracy: 0.7164 - loss: 0.5484 - val_accuracy: 0.7018 - val_loss: 0.5650 - learning_rate: 1.0000e-04
# Epoch 4/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8015 - loss: 0.4307
# Epoch 4: val_accuracy improved from 0.70181 to 0.78448, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.8015 - loss: 0.4307 - val_accuracy: 0.7845 - val_loss: 0.4573 - learning_rate: 1.0000e-04
# Epoch 5/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8587 - loss: 0.3267
# Epoch 5: val_accuracy improved from 0.78448 to 0.82708, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.8587 - loss: 0.3267 - val_accuracy: 0.8271 - val_loss: 0.4072 - learning_rate: 1.0000e-04
# Epoch 6/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9247 - loss: 0.1990
# Epoch 6: val_accuracy improved from 0.82708 to 0.84985, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 92s 105ms/step - accuracy: 0.9247 - loss: 0.1990 - val_accuracy: 0.8499 - val_loss: 0.3823 - learning_rate: 1.0000e-04
# Epoch 7/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9641 - loss: 0.1032
# Epoch 7: val_accuracy did not improve from 0.84985
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 61s 70ms/step - accuracy: 0.9641 - loss: 0.1032 - val_accuracy: 0.8073 - val_loss: 0.6100 - learning_rate: 1.0000e-04
# Epoch 8/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9818 - loss: 0.0606
# Epoch 8: val_accuracy improved from 0.84985 to 0.85323, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 109s 116ms/step - accuracy: 0.9818 - loss: 0.0606 - val_accuracy: 0.8532 - val_loss: 0.4931 - learning_rate: 1.0000e-04
# Epoch 9/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9888 - loss: 0.0381
# Epoch 9: val_accuracy did not improve from 0.85323
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 54s 70ms/step - accuracy: 0.9888 - loss: 0.0381 - val_accuracy: 0.8465 - val_loss: 0.6485 - learning_rate: 1.0000e-04
# Epoch 10/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9922 - loss: 0.0322
# Epoch 10: val_accuracy did not improve from 0.85323
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.9922 - loss: 0.0323 - val_accuracy: 0.8473 - val_loss: 0.6028 - learning_rate: 1.0000e-04
# Epoch 11/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9909 - loss: 0.0288
# Epoch 11: val_accuracy did not improve from 0.85323
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.9909 - loss: 0.0288 - val_accuracy: 0.8418 - val_loss: 0.6297 - learning_rate: 1.0000e-04
# Epoch 12/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9973 - loss: 0.0097
# Epoch 12: val_accuracy improved from 0.85323 to 0.86461, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 116s 127ms/step - accuracy: 0.9973 - loss: 0.0097 - val_accuracy: 0.8646 - val_loss: 0.6256 - learning_rate: 5.0000e-05
# Epoch 13/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9999 - loss: 0.0025
# Epoch 13: val_accuracy improved from 0.86461 to 0.86841, saving model to best_cats_dogs_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 89s 139ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 0.8684 - val_loss: 0.6654 - learning_rate: 5.0000e-05
# Epoch 14/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9963 - loss: 0.0091
# Epoch 14: val_accuracy did not improve from 0.86841
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 101s 70ms/step - accuracy: 0.9963 - loss: 0.0090 - val_accuracy: 0.8659 - val_loss: 0.7105 - learning_rate: 5.0000e-05
# Epoch 15/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9988 - loss: 0.0038
# Epoch 15: val_accuracy did not improve from 0.86841
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 41s 68ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.8574 - val_loss: 0.7720 - learning_rate: 5.0000e-05
# Epoch 16/30
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9994 - loss: 0.0032
# Epoch 16: val_accuracy did not improve from 0.86841
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 41s 69ms/step - accuracy: 0.9994 - loss: 0.0032 - val_accuracy: 0.8558 - val_loss: 0.8868 - learning_rate: 5.0000e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.85      1186
#          1.0       0.84      0.87      0.85      1185
#
#     accuracy                           0.85      2371
#    macro avg       0.85      0.85      0.85      2371
# weighted avg       0.85      0.85      0.85      2371

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 8))  # أضف حجم الشكل لتحسين العرض
# الرسم الأول: الخسارة
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss")
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend(loc='best', shadow=True)

# الرسم الثاني: الدقة
ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
ax[1].legend(loc='best', shadow=True)

# عرض الرسوم
plt.tight_layout()
plt.show()

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 148, 148, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 146, 146, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 71, 71, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 69, 69, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 34, 34, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 34, 34, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 147968)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │      37,880,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 114,519,749 (436.86 MB)
#  Trainable params: 38,173,249 (145.62 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 76,346,500 (291.24 MB)
# None

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

model_path = r"/content/best_cats_dogs_model.keras"
model = load_model(model_path)
image_path = r"/content/OIP (4).jpg"
img = load_img(image_path, target_size=(150, 150))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

prediction = model.predict(img_array)
if prediction[0][0] > 0.5:
    label = f"The image is a *Dog* with probability {prediction[0][0]:.2f}"
else:
    label = f"The image is a *Cat* with probability {1 - prediction[0][0]:.2f}"
plt.figure(figsize=(6, 6))
plt.imshow(load_img(image_path))
plt.title(label, fontsize=12, color="blue")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step

# %% [markdown]
# # CNN4

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report
def create_model():
    model = Sequential()
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(150, 150, 3)))
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Flatten())
    model.add(Dense(units=256, activation='relu'))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
model = create_model()
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
checkpoint = ModelCheckpoint("best_cats_dogs_model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    batch_size=8,
    epochs=30,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, early_stopping, learning_rate_reduction]
)
y_pred = (model.predict(X_val) > 0.5).astype("int32")
print('Classification Report:\n', classification_report(y_val, y_pred))
# Out:
# Epoch 1/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5120 - loss: 0.7003
# Epoch 1: val_accuracy improved from -inf to 0.57191, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 86s 62ms/step - accuracy: 0.5120 - loss: 0.7003 - val_accuracy: 0.5719 - val_loss: 0.6695 - learning_rate: 1.0000e-04
# Epoch 2/30
# 1185/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6130 - loss: 0.6586
# Epoch 2: val_accuracy improved from 0.57191 to 0.70055, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 132s 62ms/step - accuracy: 0.6130 - loss: 0.6586 - val_accuracy: 0.7005 - val_loss: 0.5897 - learning_rate: 1.0000e-04
# Epoch 3/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7135 - loss: 0.5655
# Epoch 3: val_accuracy improved from 0.70055 to 0.74779, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 71s 60ms/step - accuracy: 0.7135 - loss: 0.5655 - val_accuracy: 0.7478 - val_loss: 0.5136 - learning_rate: 1.0000e-04
# Epoch 4/30
# 1185/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7905 - loss: 0.4554
# Epoch 4: val_accuracy improved from 0.74779 to 0.80472, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 86s 63ms/step - accuracy: 0.7905 - loss: 0.4554 - val_accuracy: 0.8047 - val_loss: 0.4344 - learning_rate: 1.0000e-04
# Epoch 5/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8631 - loss: 0.3237
# Epoch 5: val_accuracy improved from 0.80472 to 0.82328, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 81s 62ms/step - accuracy: 0.8631 - loss: 0.3237 - val_accuracy: 0.8233 - val_loss: 0.3996 - learning_rate: 1.0000e-04
# Epoch 6/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9261 - loss: 0.1900
# Epoch 6: val_accuracy improved from 0.82328 to 0.83214, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 78s 59ms/step - accuracy: 0.9261 - loss: 0.1900 - val_accuracy: 0.8321 - val_loss: 0.4904 - learning_rate: 1.0000e-04
# Epoch 7/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9675 - loss: 0.0916
# Epoch 7: val_accuracy improved from 0.83214 to 0.83593, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 69s 58ms/step - accuracy: 0.9675 - loss: 0.0916 - val_accuracy: 0.8359 - val_loss: 0.5021 - learning_rate: 1.0000e-04
# Epoch 8/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9849 - loss: 0.0474
# Epoch 8: val_accuracy improved from 0.83593 to 0.84437, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 88s 63ms/step - accuracy: 0.9849 - loss: 0.0474 - val_accuracy: 0.8444 - val_loss: 0.5510 - learning_rate: 1.0000e-04
# Epoch 9/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9888 - loss: 0.0313
# Epoch 9: val_accuracy improved from 0.84437 to 0.84817, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 80s 61ms/step - accuracy: 0.9888 - loss: 0.0313 - val_accuracy: 0.8482 - val_loss: 0.6199 - learning_rate: 1.0000e-04
# Epoch 10/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9928 - loss: 0.0237
# Epoch 10: val_accuracy did not improve from 0.84817
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 47s 40ms/step - accuracy: 0.9928 - loss: 0.0237 - val_accuracy: 0.8292 - val_loss: 0.7902 - learning_rate: 1.0000e-04
# Epoch 11/30
# 1185/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9943 - loss: 0.0212
# Epoch 11: val_accuracy did not improve from 0.84817
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 82s 40ms/step - accuracy: 0.9943 - loss: 0.0212 - val_accuracy: 0.8203 - val_loss: 0.9030 - learning_rate: 1.0000e-04
# Epoch 12/30
# 1185/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9930 - loss: 0.0207
# Epoch 12: val_accuracy did not improve from 0.84817
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 82s 40ms/step - accuracy: 0.9930 - loss: 0.0207 - val_accuracy: 0.8385 - val_loss: 0.8605 - learning_rate: 1.0000e-04
# Epoch 13/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9975 - loss: 0.0094
# Epoch 13: val_accuracy improved from 0.84817 to 0.85112, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 107s 61ms/step - accuracy: 0.9975 - loss: 0.0094 - val_accuracy: 0.8511 - val_loss: 0.7935 - learning_rate: 5.0000e-05
# Epoch 14/30
# 1185/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9995 - loss: 0.0026
# Epoch 14: val_accuracy did not improve from 0.85112
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 49s 41ms/step - accuracy: 0.9995 - loss: 0.0026 - val_accuracy: 0.8452 - val_loss: 1.0065 - learning_rate: 5.0000e-05
# Epoch 15/30
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9990 - loss: 0.0035
# Epoch 15: val_accuracy improved from 0.85112 to 0.85449, saving model to best_cats_dogs_model.keras
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 80s 67ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.8545 - val_loss: 0.9595 - learning_rate: 5.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.83      0.81      0.82      1186
#          1.0       0.82      0.83      0.82      1185
#
#     accuracy                           0.82      2371
#    macro avg       0.82      0.82      0.82      2371
# weighted avg       0.82      0.82      0.82      2371

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 8))
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss")
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend(loc='best', shadow=True)


ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r', label="Validation accuracy")
ax[1].set_title("Accuracy")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy")
ax[1].legend(loc='best', shadow=True)

plt.tight_layout()
plt.show()

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 148, 148, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 146, 146, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 71, 71, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 69, 69, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 34, 34, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 34, 34, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 147968)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │      37,880,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 114,519,749 (436.86 MB)
#  Trainable params: 38,173,249 (145.62 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 76,346,500 (291.24 MB)
# None

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

model_path = r"/content/best_cats_dogs_model.keras"
model = load_model(model_path)
image_path = r"/content/OIP (4).jpg"
img = load_img(image_path, target_size=(150, 150))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

prediction = model.predict(img_array)
if prediction[0][0] > 0.5:
    label = f"The image is a *Dog* with probability {prediction[0][0]:.2f}"
else:
    label = f"The image is a *Cat* with probability {1 - prediction[0][0]:.2f}"
plt.figure(figsize=(6, 6))
plt.imshow(load_img(image_path))
plt.title(label, fontsize=12, color="blue")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

model_path = r"/content/best_cats_dogs_model.keras"
model = load_model(model_path)


image_path = r"/content/golden-retriever-bokeh-labrador-lawn-dogs.jpg"
img = load_img(image_path, target_size=(150, 150))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0
prediction = model.predict(img_array)

if prediction[0][0] > 0.5:
    label = f"The image is a *Dog* with probability {prediction[0][0]:.2f}"
else:
    label = f"The image is a *Cat* with probability {1 - prediction[0][0]:.2f}"
plt.figure(figsize=(6, 6))
plt.imshow(load_img(image_path))
plt.title(label, fontsize=12, color="blue")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step
